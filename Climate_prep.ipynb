# %% [markdown]
# <a href="https://colab.research.google.com/github/Nawshin-25/Geo_Analysis/blob/Analysis/Climate_prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install cartopy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 44.7 MB/s eta 0:00:00
# ...

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
file_name = '/content/drive/MyDrive/CC_CHA/Precepitation.nc'
ds = xr.open_dataset(file_name)
print (ds)
precipitation = ds['tp']
time = ds['valid_time']
# Out:
# <xarray.Dataset> Size: 21MB
# Dimensions:     (valid_time: 29952, latitude: 13, longitude: 13)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 240kB 1980-01-01 ... 2020-12-31T1...
#   * latitude    (latitude) float64 104B 23.0 22.75 22.5 ... 20.5 20.25 20.0
#   * longitude   (longitude) float64 104B 90.0 90.25 90.5 ... 92.5 92.75 93.0
#     expver      (valid_time) <U4 479kB ...
# Data variables:
#     tp          (valid_time, latitude, longitude) float32 20MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-03-24T19:43 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
time = pd.to_datetime(time.values)
climatology = precipitation.groupby('valid_time.month').mean('valid_time')
precipitation_anomaly = precipitation.groupby('valid_time.month') - climatology
precipitation_anomaly_annual = precipitation_anomaly.resample(valid_time='Y').mean()
years = precipitation_anomaly_annual.valid_time.dt.year.values
precipitation_anomaly_values = precipitation_anomaly_annual.mean(dim=['latitude', 'longitude']).values
valid_indices = ~np.isnan(precipitation_anomaly_values)  # Get indices where values are valid
years_clean = years[valid_indices]
precipitation_anomaly_clean = precipitation_anomaly_values[valid_indices]
slope, intercept, r_value, p_value, std_err = linregress(years_clean, precipitation_anomaly_clean)
trendline = slope * years_clean + intercept  # Compute trendline values
# Out:
# /usr/local/lib/python3.11/dist-packages/xarray/groupers.py:487: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.index_grouper = pd.Grouper(

# %%
plt.figure(figsize=(10, 5))
plt.plot(years_clean, precipitation_anomaly_clean, marker='o', linestyle='-', label='Precipitation Anomaly')
plt.plot(years_clean, trendline, color='red', linestyle='--', linewidth=2, label=f'Trend (Slope={slope:.4f}mm/year)')
plt.axhline(0, color='black', linestyle='--', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Precipitation Anomaly (mm)')
plt.title('Annual Precipitation Anomaly (1980-2020) with Trendline')
plt.legend()
plt.grid()
plt.show()

# %%
climatology = precipitation.groupby('valid_time.month').mean('valid_time')
precipitation_anomaly = precipitation.groupby('valid_time.month') - climatology
precipitation_anomaly_annual = precipitation_anomaly.resample(valid_time='Y').mean()

years = precipitation_anomaly_annual.valid_time.dt.year.values
precipitation_anomaly_values = precipitation_anomaly_annual.mean(dim=['latitude', 'longitude']).values

valid_indices = ~np.isnan(precipitation_anomaly_values)  # Get indices where values are valid
years_clean = years[valid_indices]
precipitation_anomaly_clean = precipitation_anomaly_values[valid_indices]

# Define time periods
time_periods = [
    (1981, 1990),
    (1991, 2000),
    (2001, 2010),
    (2011, 2020)
]
# Out:
# /usr/local/lib/python3.11/dist-packages/xarray/groupers.py:487: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.index_grouper = pd.Grouper(

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharey=True)

for i, (start, end) in enumerate(time_periods):
    ax = axes[i // 2, i % 2]  # Position in subplot grid

    mask = (years_clean >= start) & (years_clean <= end)
    years_subset = years_clean[mask]
    precipitation_anomaly_subset = precipitation_anomaly_clean[mask]

    if len(years_subset) > 1:  # Ensure there are enough points for regression
        slope, intercept, r_value, p_value, std_err = linregress(years_subset, precipitation_anomaly_subset)
        trendline = slope * years_subset + intercept
        ax.plot(years_subset, trendline, color='red', linestyle='--', linewidth=2, label=f'Trend (Slope={slope:.4f}mm/year)')

    ax.plot(years_subset, precipitation_anomaly_subset, marker='o', linestyle='-', label='Precipitation Anomaly')

    ax.set_title(f'Precipitation Anomaly ({start}-{end})')
    ax.axhline(0, color='black', linestyle='--', linewidth=1)
    ax.set_xlabel('Year')
    if i % 2 == 0:
        ax.set_ylabel('Precipitation Anomaly (mm)')
    ax.legend()
    ax.grid()

plt.tight_layout()
plt.suptitle('Precipitation Anomaly Over Different Decades (1981-2020)', fontsize=14, y=1.02)
plt.show()

# %%
seasons = {
    "Premonsoon (Feb-Apr)": [2, 3, 4],
    "Monsoon (May-Jul)": [5, 6, 7],
    "Postmonsoon (Aug-Oct)": [8, 9, 10],
    "Winter (Nov-Jan)": [11, 12, 1]
}

climatology = precipitation.groupby('valid_time.month').mean('valid_time')
precipitation_anomaly = precipitation.groupby('valid_time.month') - climatology

time_periods = [
    (1981, 1990),
    (1991, 2000),
    (2001, 2010),
    (2011, 2020)
]

# %%
for season_name, months in seasons.items():
    fig, axes = plt.subplots(2, 2, figsize=(8, 8), subplot_kw={'projection': ccrs.PlateCarree()})
    fig.subplots_adjust(right=0.85)  # Adjust layout to prevent overlap

    # Create an axis for the colorbar
    cbar_ax = fig.add_axes([0.88, 0.3, 0.02, 0.4])  # [left, bottom, width, height]

    for i, (start, end) in enumerate(time_periods):
        ax = axes[i // 2, i % 2]  # Position in subplot grid

        # Create a mask to filter data for the current season and decade.
        if 1 in months:  # Special handling for Winter (Nov, Dec, Jan)
            mask = (((time.dt.year == start) & (time.dt.month.isin([11, 12]))) |
                    ((time.dt.year == start+1) & (time.dt.month == 1)))
            for yr in range(start+1, end):
                mask = mask | (((time.dt.year == yr) & (time.dt.month.isin([11, 12]))) |
                               ((time.dt.year == yr+1) & (time.dt.month == 1)))
            precipitation_seasonal_anomaly = precipitation_anomaly.sel(valid_time=mask).mean(dim='valid_time')
        else:
            mask = (time.dt.year >= start) & (time.dt.year <= end) & (time.dt.month.isin(months))
            precipitation_seasonal_anomaly = precipitation_anomaly.sel(valid_time=mask).mean(dim='valid_time')

        # Plot the spatial anomaly
        im = ax.pcolormesh(ds.longitude, ds.latitude, precipitation_seasonal_anomaly, cmap='coolwarm', transform=ccrs.PlateCarree())
        ax.add_feature(cfeature.LAND, color='lightgray')
        ax.add_feature(cfeature.COASTLINE, linewidth=1)
        ax.set_title(f'{start}-{end}')
        ax.set_xlabel('Longitude')
        ax.set_ylabel('Latitude')

    # Add a common colorbar outside the plot
    cbar = fig.colorbar(im, cax=cbar_ax)
    cbar.set_label('Precipitation Anomaly (°C)')

    plt.suptitle(f'Precipitation Anomaly for {season_name}', fontsize=14, y=0.98)
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Prevent overlap
    plt.show()
# Out:
# <ipython-input-18-bbd89225d99c>:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.85, 1])  # Prevent overlap
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.11/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# <ipython-input-18-bbd89225d99c>:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.85, 1])  # Prevent overlap
# ...
